# %% [markdown]
# # Natural Language Processing-Step-06

# %% [markdown]
# ### 01.Read the data

# %%
import pandas as pd
data_text = pd.read_csv('SMSSpamCollection.tsv', sep='\t',names=['label','body_text'],header=None)
data_text.head()
# Out:
#   label                                          body_text
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!

# %% [markdown]
# ### 02.Remove Punctuations

# %%
import string
string.punctuation
def remove_punctuation(text):
    text_nopunct="".join([char for char in text if char not in string.punctuation])
    return text_nopunct

data_text['body_text_clean']=data_text['body_text'].apply(lambda x: remove_punctuation(x))
data_text.head()
# Out:
#   label                                          body_text  \
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                      body_text_clean
# 0  Ive been searching for the right words to than...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  Nah I dont think he goes to usf he lives aroun...
# 3  Even my brother is not like to speak with me T...
# 4                  I HAVE A DATE ON SUNDAY WITH WILL

# %% [markdown]
# ### 03.Tokenization

# %%
import re
def tokenize(text):
    tokens=re.split('\W+',text)
    return tokens
data_text['body_text_tokenized']=data_text['body_text_clean'].apply(lambda x:tokenize(x))
data_text.head()
# Out:
#   label                                          body_text  \
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                      body_text_clean  \
# 0  Ive been searching for the right words to than...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  Nah I dont think he goes to usf he lives aroun...
# 3  Even my brother is not like to speak with me T...
# 4                  I HAVE A DATE ON SUNDAY WITH WILL
#
#                                  body_text_tokenized
# 0  [Ive, been, searching, for, the, right, words,...
# 1  [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 2  [Nah, I, dont, think, he, goes, to, usf, he, l...
# 3  [Even, my, brother, is, not, like, to, speak, ...
# 4         [I, HAVE, A, DATE, ON, SUNDAY, WITH, WILL]

# %% [markdown]
# ### 04.Remove stop words

# %%
import nltk
stopword = nltk.corpus.stopwords.words('english')
def remove_stopwords(tokenized_list):
    text=[word for word in tokenized_list if word not in stopword]
    return text
data_text['body_text_nostop']=data_text['body_text_tokenized'].apply(lambda x:remove_stopwords(x))
data_text.head()
# Out:
#   label                                          body_text  \
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                      body_text_clean  \
# 0  Ive been searching for the right words to than...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  Nah I dont think he goes to usf he lives aroun...
# 3  Even my brother is not like to speak with me T...
# 4                  I HAVE A DATE ON SUNDAY WITH WILL
#
#                                  body_text_tokenized  \
# 0  [Ive, been, searching, for, the, right, words,...
# 1  [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 2  [Nah, I, dont, think, he, goes, to, usf, he, l...
# 3  [Even, my, brother, is, not, like, to, speak, ...
# 4         [I, HAVE, A, DATE, ON, SUNDAY, WITH, WILL]
#
#                                     body_text_nostop
# 0  [Ive, searching, right, words, thank, breather...
# 1  [Free, entry, 2, wkly, comp, win, FA, Cup, fin...
# 2  [Nah, I, dont, think, goes, usf, lives, around...
# 3  [Even, brother, like, speak, They, treat, like...
# 4         [I, HAVE, A, DATE, ON, SUNDAY, WITH, WILL]

# %% [markdown]
# ### 05.Stemming

# %%
ps=nltk.PorterStemmer()
def stemming(tokenized_text):
    text=[ps.stem(word) for word in tokenized_text]
    return text
data_text['body_text_stemmed']=data_text['body_text_nostop'].apply(lambda x:stemming(x))
data_text.head()
# Out:
#   label                                          body_text  \
# 0   ham  I've been searching for the right words to tha...
# 1  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2   ham  Nah I don't think he goes to usf, he lives aro...
# 3   ham  Even my brother is not like to speak with me. ...
# 4   ham                I HAVE A DATE ON SUNDAY WITH WILL!!
#
#                                      body_text_clean  \
# 0  Ive been searching for the right words to than...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  Nah I dont think he goes to usf he lives aroun...
# 3  Even my brother is not like to speak with me T...
# 4                  I HAVE A DATE ON SUNDAY WITH WILL
#
#                                  body_text_tokenized  \
# 0  [Ive, been, searching, for, the, right, words,...
# 1  [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 2  [Nah, I, dont, think, he, goes, to, usf, he, l...
# 3  [Even, my, brother, is, not, like, to, speak, ...
# 4         [I, HAVE, A, DATE, ON, SUNDAY, WITH, WILL]
#
#                                     body_text_nostop  \
# 0  [Ive, searching, right, words, thank, breather...
# 1  [Free, entry, 2, wkly, comp, win, FA, Cup, fin...
# 2  [Nah, I, dont, think, goes, usf, lives, around...
# 3  [Even, brother, like, speak, They, treat, like...
# 4         [I, HAVE, A, DATE, ON, SUNDAY, WITH, WILL]
#
#                                    body_text_stemmed
# 0  [ive, search, right, word, thank, breather, i,...
# 1  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 2  [nah, i, dont, think, goe, usf, live, around, ...
# 3  [even, brother, like, speak, they, treat, like...
# 4         [i, have, a, date, on, sunday, with, will]

# %% [markdown]
# ### 06.Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer
wn=WordNetLemmatizer()

def lemmatizing(tokenized_text):
    text=[wn.lemmatize(word) for word in tokenized_text]
    return text
data_text['body_text_lemmatized']=data_text['body_text_stemmed'].apply(lambda x: lemmatizing(x))
data_text.head()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[30], line 7
#       5     text=[wn.lemmatize(word) for word in tokenized_text]
#       6     return text
# ----> 7 data_text['body_text_lemmatized']=data_text['body_text_stemmed'].apply(lambda x: lemmatizing(x))
#       8 data_text.head()
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[30], line 7, in <lambda>(x)
#       5     text=[wn.lemmatize(word) for word in tokenized_text]
#       6     return text
# ----> 7 data_text['body_text_lemmatized']=data_text['body_text_stemmed'].apply(lambda x: lemmatizing(x))
#       8 data_text.head()
#
# Cell In[30], line 5, in lemmatizing(tokenized_text)
#       4 def lemmatizing(tokenized_text):
# ----> 5     text=[wn.lemmatize(word) for word in tokenized_text]
#       6     return text
#
# Cell In[30], line 5, in <listcomp>(.0)
#       4 def lemmatizing(tokenized_text):
# ----> 5     text=[wn.lemmatize(word) for word in tokenized_text]
#       6     return text
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\stem\wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)
#      83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\stem\wordnet.py:41, in WordNetLemmatizer._morphy(self, form, pos, check_exceptions)
#      31 """
#      32 _morphy() is WordNet's _morphy lemmatizer.
#      33 It returns a list of all lemmas found in WordNet.
#    (...)
#      37 ['us', 'u']
#      38 """
#      39 from nltk.corpus import wordnet as wn
# ---> 41 return wn._morphy(form, pos, check_exceptions)
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\corpus\util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\data.py:551, in find(resource_name, paths)
#     549 modified_name = "/".join(pieces[:i] + [pieces[i] + ".zip"] + pieces[i:])
#     550 try:
# --> 551     return find(modified_name, paths)
#     552 except LookupError:
#     553     pass
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\data.py:538, in find(resource_name, paths)
#     536 if os.path.exists(p):
#     537     try:
# --> 538         return ZipFilePathPointer(p, zipentry)
#     539     except OSError:
#     540         # resource not in zipfile
#     541         continue
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\data.py:391, in ZipFilePathPointer.__init__(self, zipfile, entry)
#     383 """
#     384 Create a new path pointer pointing at the specified entry
#     385 in the given zipfile.
#    (...)
#     388 does not contain the specified entry.
#     389 """
#     390 if isinstance(zipfile, str):
# --> 391     zipfile = OpenOnDemandZipFile(os.path.abspath(zipfile))
#     393 # Check that the entry exists:
#     394 if entry:
#     395     # Normalize the entry string, it should be relative:
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\site-packages\nltk\data.py:1020, in OpenOnDemandZipFile.__init__(self, filename)
#    1018 if not isinstance(filename, str):
#    1019     raise TypeError("ReopenableZipFile filename must be a string")
# -> 1020 zipfile.ZipFile.__init__(self, filename)
#    1021 assert self.filename == filename
#    1022 self.close()
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\zipfile.py:1257, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1255 try:
#    1256     if mode == 'r':
# -> 1257         self._RealGetContents()
#    1258     elif mode in ('w', 'x'):
#    1259         # set the modified flag so central directory gets written
#    1260         # even if no files are added to the archive
#    1261         self._didModify = True
#
# File c:\Users\SIVA1201\anaconda3\envs\artsci\lib\zipfile.py:1324, in ZipFile._RealGetContents(self)
#    1322     raise BadZipFile("File is not a zip file")
#    1323 if not endrec:
# -> 1324     raise BadZipFile("File is not a zip file")
#    1325 if self.debug > 1:
#    1326     print(endrec)
#
# BadZipFile: File is not a zip file
